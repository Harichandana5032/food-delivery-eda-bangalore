# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\haric\\Desktop\\Task 5 elevate labs\\food_delivery_data3.csv")
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 55 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Age                                        388 non-null    int64
#  1   Gender                                     388 non-null    object
#  2   Marital Status                             388 non-null    object
#  3   Occupation                                 388 non-null    object
#  4   Monthly Income                             388 non-null    object
#  5   Educational Qualifications                 388 non-null    object
#  6   Family size                                388 non-null    int64
#  7   latitude                                   388 non-null    float64
#  8   longitude                                  388 non-null    float64
#  9   Pin code                                   388 non-null    int64
# ...

# %%
import matplotlib.pyplot as plt

df['Order Time'].value_counts().plot(kind='bar')
plt.title("Orders by Time Category")
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

sns.countplot(x='Order Time', hue='Gender', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
df['Age'].hist()
plt.title("Age Distribution")
plt.show()

# %%
df['Monthly Income'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=False)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in ['Late Delivery', 'Poor Hygiene', 'Missing item', 'Wrong order delivered']:
    sns.countplot(x=col, data=df)
    plt.title(col)
    plt.xticks(rotation=45)
    plt.show()

# %%
df['Output'].value_counts().plot(kind='bar')
plt.title("Customer Satisfaction")
plt.show()

# %%
import seaborn as sns
sns.pairplot(df[['Age', 'Family size']])
plt.show()

# %%
sns.scatterplot(x='Age', y='Family size', data=df)
plt.show()

# %% [markdown]
# ## Final Summary

# %% [markdown]
# The exploratory data analysis of food delivery preferences in Bangalore reveals that a significant portion of users belong to the non-income group, indicating a strong presence of students. Ordering behavior peaks during evenings and weekends, suggesting that food delivery is primarily driven by convenience and leisure time. Key challenges identified include late delivery and hygiene concerns, which significantly impact customer satisfaction. Overall, the analysis highlights the importance of operational efficiency and targeted marketing strategies to improve user engagement.
